# %% [markdown]
# ## [Question 1] Looking back at Scratch

# %%
"""
TensorFlow Task
"""
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
import tensorflow.compat.v1 as tf

tf.disable_v2_behavior()


dataset_path ="data/Iris.csv"
df = pd.read_csv(dataset_path)


df = df[(df["Species"] == "Iris-versicolor")|(df["Species"] == "Iris-virginica")]
y = df["Species"]
X = df.loc[:, ["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"]]
y = np.array(y)
X = np.array(X)

y[y=='Iris-versicolor'] = 0
y[y=='Iris-virginica'] = 1
y = y.astype(np.int32)[:, np.newaxis]


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

# %% [markdown]
# ## 【問題2】スクラッチとTensorFlowの対応を考える

# %%
#get mini batch 
class GetMiniBatch:
    """
    ミニバッチを取得するイテレータ

    Parameters
    ----------
    X : 次の形のndarray, shape (n_samples, n_features)
      学習データ
    y : 次の形のndarray, shape (n_samples, 1)
      正解値
    batch_size : int
      バッチサイズ
    seed : int
      NumPyの乱数のシード
    """
    def __init__(self, X, y, batch_size = 10, seed=0):
        self.batch_size = batch_size
        np.random.seed(seed)
        shuffle_index = np.random.permutation(np.arange(X.shape[0]))
        self.X = X[shuffle_index]
        self.y = y[shuffle_index]
        self._stop = np.ceil(X.shape[0]/self.batch_size).astype(np.int32)
    def __len__(self):
        return self._stop
    def __getitem__(self,item):
        p0 = item*self.batch_size
        p1 = item*self.batch_size + self.batch_size
        return self.X[p0:p1], self.y[p0:p1]        
    def __iter__(self):
        self._counter = 0
        return self
    def __next__(self):
        if self._counter >= self._stop:
            raise StopIteration()
        p0 = self._counter*self.batch_size
        p1 = self._counter*self.batch_size + self.batch_size
        self._counter += 1
        return self.X[p0:p1], self.y[p0:p1]


#hyperparameters 
learning_rate = 0.001
batch_size = 8
num_epochs = 100

n_hidden1 = 64
n_hidden2 = 128
n_input = X_train.shape[1]
n_samples = X_train.shape[0]
n_classes = 1

# tensorflow array 
X = tf.placeholder("float", [None, n_input])
Y = tf.placeholder("float", [None, n_classes])

## dataloader 
get_mini_batch_train = GetMiniBatch(X_train, y_train, batch_size=batch_size)

# model architecture
def example_net(x):

    weights = {
        'w1': tf.Variable(tf.random_normal([n_input, n_hidden1])),
        'w2': tf.Variable(tf.random_normal([n_hidden1, n_hidden2])),
        'w3': tf.Variable(tf.random_normal([n_hidden2, n_classes]))
    }
    biases = {
        'b1': tf.Variable(tf.random_normal([n_hidden1])),
        'b2': tf.Variable(tf.random_normal([n_hidden2])),
        'b3': tf.Variable(tf.random_normal([n_classes]))
    }

    layer_1 = tf.add(tf.matmul(x, weights['w1']), biases['b1'])
    layer_1 = tf.nn.relu(layer_1)
    layer_2 = tf.add(tf.matmul(layer_1, weights['w2']), biases['b2'])
    layer_2 = tf.nn.relu(layer_2)
    layer_output = tf.matmul(layer_2, weights['w3']) + biases['b3'] # tf.addと+は等価である
    return layer_output

# model with initialized parameters                       
logits = example_net(X)


#loss function 
loss_op = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(labels=Y, logits=logits))

# optimizer 
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss_op)

## accuracy 
correct_pred = tf.equal(tf.sign(Y - 0.5), tf.sign(tf.sigmoid(logits) - 0.5))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

print("Not trained model's accuracy:", accuracy)


### initialize training process
init = tf.global_variables_initializer()
with tf.Session() as sess:
    sess.run(init)
    for epoch in range(num_epochs):
        total_batch = np.ceil(X_train.shape[0]/batch_size).astype(np.int32)
        total_loss = 0
        total_acc = 0
        for i, (mini_batch_x, mini_batch_y) in enumerate(get_mini_batch_train):
            sess.run(train_op, feed_dict={X: mini_batch_x, Y: mini_batch_y})
            loss, acc = sess.run([loss_op, accuracy], feed_dict={X: mini_batch_x, Y: mini_batch_y})
            total_loss += loss
            total_acc += acc
        total_loss /= n_samples
        total_acc /= n_samples
        val_loss, val_acc = sess.run([loss_op, accuracy], feed_dict={X: X_val, Y: y_val})
        print("Epoch {}, loss : {:.4f}, val_loss : {:.4f}, acc : {:.3f}, val_acc : {:.3f}".format(epoch, loss, val_loss, acc, val_acc))
    test_acc = sess.run(accuracy, feed_dict={X: X_test, Y: y_test})
    print("test_acc : {:.3f}".format(test_acc))
# Out:
# WARNING:tensorflow:From C:\Users\bilguun.ERDENETMC\AppData\Local\Temp\ipykernel_17148\1515291775.py:89: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# Not trained model's accuracy: Tensor("Mean_1:0", shape=(), dtype=float32)
# Epoch 0, loss : 395.4276, val_loss : 234.6354, acc : 0.375, val_acc : 0.625
# Epoch 1, loss : 306.6858, val_loss : 183.4991, acc : 0.375, val_acc : 0.625
# Epoch 2, loss : 217.6712, val_loss : 132.4193, acc : 0.375, val_acc : 0.625
# Epoch 3, loss : 128.0752, val_loss : 80.6499, acc : 0.375, val_acc : 0.625
# Epoch 4, loss : 38.7443, val_loss : 27.6968, acc : 0.375, val_acc : 0.625
# Epoch 5, loss : 4.1947, val_loss : 9.3533, acc : 0.750, val_acc : 0.500
# Epoch 6, loss : 11.5217, val_loss : 19.8681, acc : 0.625, val_acc : 0.438
# Epoch 7, loss : 0.5076, val_loss : 2.8441, acc : 0.875, val_acc : 0.750
# Epoch 8, loss : 0.5650, val_loss : 3.9911, acc : 0.875, val_acc : 0.750
# Epoch 9, loss : 0.0000, val_loss : 2.0346, acc : 1.000, val_acc : 0.875
# Epoch 10, loss : 0.0000, val_loss : 1.0437, acc : 1.000, val_acc : 0.875
# Epoch 11, loss : 0.0000, val_loss : 1.0494, acc : 1.000, val_acc : 0.812
# Epoch 12, loss : 0.0000, val_loss : 1.0524, acc : 1.000, val_acc : 0.875
# Epoch 13, loss : 0.0000, val_loss : 1.1320, acc : 1.000, val_acc : 0.875
# Epoch 14, loss : 0.0000, val_loss : 1.0618, acc : 1.000, val_acc : 0.875
# Epoch 15, loss : 0.0000, val_loss : 1.0208, acc : 1.000, val_acc : 0.875
# Epoch 16, loss : 0.0000, val_loss : 1.0154, acc : 1.000, val_acc : 0.875
# Epoch 17, loss : 0.0000, val_loss : 1.0195, acc : 1.000, val_acc : 0.875
# Epoch 18, loss : 0.0000, val_loss : 1.0017, acc : 1.000, val_acc : 0.875
# Epoch 19, loss : 0.0000, val_loss : 0.9633, acc : 1.000, val_acc : 0.875
# Epoch 20, loss : 0.0000, val_loss : 0.9242, acc : 1.000, val_acc : 0.875
# Epoch 21, loss : 0.0000, val_loss : 0.8888, acc : 1.000, val_acc : 0.875
# Epoch 22, loss : 0.0000, val_loss : 0.8594, acc : 1.000, val_acc : 0.875
# Epoch 23, loss : 0.0000, val_loss : 0.8316, acc : 1.000, val_acc : 0.875
# Epoch 24, loss : 0.0000, val_loss : 0.8058, acc : 1.000, val_acc : 0.875
# Epoch 92, loss : 0.0000, val_loss : 0.5264, acc : 1.000, val_acc : 0.875
# Epoch 93, loss : 0.0000, val_loss : 0.5190, acc : 1.000, val_acc : 0.875
# Epoch 94, loss : 0.0000, val_loss : 0.5135, acc : 1.000, val_acc : 0.875
# Epoch 95, loss : 0.0000, val_loss : 0.5087, acc : 1.000, val_acc : 0.875
# Epoch 96, loss : 0.0000, val_loss : 0.5040, acc : 1.000, val_acc : 0.875
# Epoch 97, loss : 0.0000, val_loss : 0.4995, acc : 1.000, val_acc : 0.875
# Epoch 98, loss : 0.0000, val_loss : 0.4996, acc : 1.000, val_acc : 0.875
# Epoch 99, loss : 0.0000, val_loss : 0.5018, acc : 1.000, val_acc : 0.875
# test_acc : 0.900

# %% [markdown]
# ## [Problem 3] Create a model for Iris using all three objective variables

# %%
from sklearn.preprocessing import OneHotEncoder

dataset_path ="data/Iris.csv"
df = pd.read_csv(dataset_path)

y = df["Species"]
X = df.loc[:, ["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"]]
y = np.array(y)
X = np.array(X)

y[y=='Iris-versicolor'] = 0
y[y=='Iris-virginica'] = 1
y[y=='Iris-setosa'] = 2

enc = OneHotEncoder(handle_unknown='ignore')
y = enc.fit_transform(y[:,np.newaxis]).toarray()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

# %%
y_train.shape
# Out:
# (96, 3)

# %%
class GetMiniBatch:
    """
    ミニバッチを取得するイテレータ

    Parameters
    ----------
    X : 次の形のndarray, shape (n_samples, n_features)
      学習データ
    y : 次の形のndarray, shape (n_samples, 1)
      正解値
    batch_size : int
      バッチサイズ
    seed : int
      NumPyの乱数のシード
    """
    def __init__(self, X, y, batch_size = 10, seed=0):
        self.batch_size = batch_size
        np.random.seed(seed)
        shuffle_index = np.random.permutation(np.arange(X.shape[0]))
        self.X = X[shuffle_index]
        self.y = y[shuffle_index]
        self._stop = np.ceil(X.shape[0]/self.batch_size).astype(np.int32)
    def __len__(self):
        return self._stop
    def __getitem__(self,item):
        p0 = item*self.batch_size
        p1 = item*self.batch_size + self.batch_size
        return self.X[p0:p1], self.y[p0:p1]        
    def __iter__(self):
        self._counter = 0
        return self
    def __next__(self):
        if self._counter >= self._stop:
            raise StopIteration()
        p0 = self._counter*self.batch_size
        p1 = self._counter*self.batch_size + self.batch_size
        self._counter += 1
        return self.X[p0:p1], self.y[p0:p1]

# %%
learning_rate = 0.01
batch_size = 8
num_epochs = 100

n_hidden1 = 64
n_hidden2 = 128
n_input = X_train.shape[1]
n_samples = X_train.shape[0]
n_classes = 3

X = tf.placeholder("float", [None, n_input])
Y = tf.placeholder("float", [None, n_classes])

get_mini_batch_train = GetMiniBatch(X_train, y_train, batch_size=batch_size)

def example_net(x):
    """
    単純な3層ニューラルネットワーク
    """

   
    weights = {
        'w1': tf.Variable(tf.random_normal([n_input, n_hidden1])),
        'w2': tf.Variable(tf.random_normal([n_hidden1, n_hidden2])),
        'w3': tf.Variable(tf.random_normal([n_hidden2, n_classes]))
    }
    biases = {
        'b1': tf.Variable(tf.random_normal([n_hidden1])),
        'b2': tf.Variable(tf.random_normal([n_hidden2])),
        'b3': tf.Variable(tf.random_normal([n_classes]))
    }

    layer_1 = tf.add(tf.matmul(x, weights['w1']), biases['b1'])
    layer_1 = tf.nn.relu(layer_1)
    layer_2 = tf.add(tf.matmul(layer_1, weights['w2']), biases['b2'])
    layer_2 = tf.nn.relu(layer_2)
    layer_output = tf.matmul(layer_2, weights['w3']) + biases['b3'] # tf.addと+は等価である
    return layer_output

#model initiliaze                            
logits = example_net(X)
loss_op = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=Y, logits=logits))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss_op)
correct_pred = tf.equal(tf.argmax(Y, 1), tf.argmax(tf.nn.softmax(logits), 1))

#not trained model's accuracy
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

## training 
init = tf.global_variables_initializer()
with tf.Session() as sess:
    sess.run(init)
    for epoch in range(num_epochs):
        total_batch = np.ceil(X_train.shape[0]/batch_size).astype(np.int32)
        total_loss = 0
        total_acc = 0
        for i, (mini_batch_x, mini_batch_y) in enumerate(get_mini_batch_train):
            sess.run(train_op, feed_dict={X: mini_batch_x, Y: mini_batch_y})
            loss, acc = sess.run([loss_op, accuracy], feed_dict={X: mini_batch_x, Y: mini_batch_y})
            total_loss += loss
            total_acc += acc
        total_loss /= n_samples
        total_acc /= n_samples
        val_loss, val_acc = sess.run([loss_op, accuracy], feed_dict={X: X_val, Y: y_val})
        print("Epoch {}, loss : {:.4f}, val_loss : {:.4f}, acc : {:.3f}, val_acc : {:.3f}".format(epoch, loss, val_loss, acc, val_acc))
    test_acc = sess.run(accuracy, feed_dict={X: X_test, Y: y_test})
    print("test_acc : {:.3f}".format(test_acc))
# Out:
# Epoch 0, loss : 15.5792, val_loss : 31.9068, acc : 0.750, val_acc : 0.625
# Epoch 1, loss : 0.0000, val_loss : 5.8892, acc : 1.000, val_acc : 0.833
# Epoch 2, loss : 0.0000, val_loss : 4.3924, acc : 1.000, val_acc : 0.917
# Epoch 3, loss : 0.7215, val_loss : 2.7327, acc : 0.875, val_acc : 0.833
# Epoch 4, loss : 0.0000, val_loss : 4.1587, acc : 1.000, val_acc : 0.917
# Epoch 5, loss : 0.0000, val_loss : 1.0440, acc : 1.000, val_acc : 0.833
# Epoch 6, loss : 0.0000, val_loss : 3.7901, acc : 1.000, val_acc : 0.917
# Epoch 7, loss : 0.0000, val_loss : 0.9841, acc : 1.000, val_acc : 0.833
# Epoch 8, loss : 0.0000, val_loss : 1.8347, acc : 1.000, val_acc : 0.917
# Epoch 9, loss : 0.0000, val_loss : 1.1402, acc : 1.000, val_acc : 0.917
# Epoch 10, loss : 0.0000, val_loss : 1.3186, acc : 1.000, val_acc : 0.917
# Epoch 11, loss : 0.0000, val_loss : 0.9661, acc : 1.000, val_acc : 0.917
# Epoch 12, loss : 0.0000, val_loss : 2.4646, acc : 1.000, val_acc : 0.917
# Epoch 13, loss : 0.0000, val_loss : 4.4560, acc : 1.000, val_acc : 0.917
# Epoch 14, loss : 0.0000, val_loss : 2.2233, acc : 1.000, val_acc : 0.917
# Epoch 15, loss : 0.0000, val_loss : 4.8545, acc : 1.000, val_acc : 0.917
# Epoch 16, loss : 0.0000, val_loss : 1.4545, acc : 1.000, val_acc : 0.917
# Epoch 17, loss : 0.2352, val_loss : 3.2678, acc : 0.875, val_acc : 0.875
# Epoch 86, loss : 0.0000, val_loss : 5.6010, acc : 1.000, val_acc : 0.917
# Epoch 87, loss : 0.0000, val_loss : 2.3959, acc : 1.000, val_acc : 0.833
# Epoch 88, loss : 0.0000, val_loss : 4.5678, acc : 1.000, val_acc : 0.917
# Epoch 89, loss : 0.0000, val_loss : 5.8668, acc : 1.000, val_acc : 0.917
# Epoch 90, loss : 1.3896, val_loss : 5.3446, acc : 0.875, val_acc : 0.875
# Epoch 91, loss : 0.0000, val_loss : 3.4584, acc : 1.000, val_acc : 0.917
# Epoch 92, loss : 1.3511, val_loss : 15.8997, acc : 0.875, val_acc : 0.750
# Epoch 93, loss : 1.2258, val_loss : 3.1037, acc : 0.875, val_acc : 0.833
# Epoch 94, loss : 0.0000, val_loss : 6.4322, acc : 1.000, val_acc : 0.917
# Epoch 95, loss : 0.0000, val_loss : 12.0766, acc : 1.000, val_acc : 0.792
# Epoch 96, loss : 4.7437, val_loss : 8.7003, acc : 0.875, val_acc : 0.750
# Epoch 97, loss : 0.0000, val_loss : 6.1187, acc : 1.000, val_acc : 0.917
# Epoch 98, loss : 0.0004, val_loss : 3.0289, acc : 1.000, val_acc : 0.833
# Epoch 99, loss : 0.0000, val_loss : 5.7629, acc : 1.000, val_acc : 0.917
# test_acc : 0.967

# %% [markdown]
# ## 【問題4】House Pricesのモデルを作成

# %%
import pandas as pd
import numpy as np
data_ori = pd.read_csv("data//train.csv")

# %%
max_num_of_row = len(data_ori)
data_loss_rate = data_ori.isnull().sum() / max_num_of_row * 100

# %%
data_drop_5nan_col = data_ori.dropna(axis=1, thresh=max_num_of_row-5)
print("before:{}".format(len(data_ori.columns.values)))
print("after:{}".format(len(data_drop_5nan_col.columns.values)))
# Out:
# before:81
# after:63

# %%
data_to_use = data_drop_5nan_col.dropna(axis=0)
data_to_use = data_to_use.reset_index(drop=True)

# %%
col_featuer = ['OverallQual',
               'GrLivArea',
               'GarageCars',
               'GarageArea',
               'TotalBsmtSF',
               '1stFlrSF',
               'FullBath',
               'TotRmsAbvGrd',
               'YearBuilt',
               'YearRemodAdd',
              ]

col_target = ['SalePrice']

cols = col_featuer + col_target

# %%
data = data_to_use[cols]

# %%
import gc 
gc.enable()
gc.collect()
# Out:
# 2364

# %%
del data_ori, data_drop_5nan_col, data_to_use
gc.collect()
# Out:
# 0

# %%
X = data[col_featuer].values
Y = data[col_target].values

# %%
# data split to train, validation and test 
# train for model training 
# validation for model selection
# test for model evaluation 
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=0)

# %%
# hyperparameters
learning_rate = 0.01
batch_size = 10
num_epochs = 100
n_hidden1 = 50
n_hidden2 = 100
n_input = x_train.shape[1]
n_samples = x_train.shape[0]
n_classes = 1

# tf tensors
X = tf.placeholder("float", [None, n_input])
Y = tf.placeholder("float", [None, n_classes])

# dataloader 
get_mini_batch_train = GetMiniBatch(x_train, y_train, batch_size=batch_size)

# model 
def example_net(x):
    """
    単純な3層ニューラルネットワーク
    """

    weights = {
        'w1': tf.Variable(tf.random_normal([n_input, n_hidden1])),
        'w2': tf.Variable(tf.random_normal([n_hidden1, n_hidden2])),
        'w3': tf.Variable(tf.random_normal([n_hidden2, n_classes]))
    }
    biases = {
        'b1': tf.Variable(tf.random_normal([n_hidden1])),
        'b2': tf.Variable(tf.random_normal([n_hidden2])),
        'b3': tf.Variable(tf.random_normal([n_classes]))
    }

    layer_1 = tf.add(tf.matmul(x, weights['w1']), biases['b1'])
    layer_1 = tf.nn.relu(layer_1)
    layer_2 = tf.add(tf.matmul(layer_1, weights['w2']), biases['b2'])
    layer_2 = tf.nn.relu(layer_2)
    layer_output = tf.matmul(layer_2, weights['w3']) + biases['b3'] # tf.addと+は等価である
    return layer_output

# not trained model's prediction                             
pred = example_net(X)

# loss for regression 
# mean absolute loss is good for outliers 
loss_op = tf.reduce_mean(tf.abs(Y - pred))

# optimizer 
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss_op)

# evaluation metric
r_square = 1 - (tf.reduce_sum(tf.square(Y - pred)) / tf.reduce_sum(tf.square(Y - tf.reduce_mean(Y))))

#training 
init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(num_epochs):
        total_batch = np.ceil(X_train.shape[0]/batch_size).astype(np.int32)
        total_loss = 0
        total_r_square = 0
        for i, (mini_batch_x, mini_batch_y) in enumerate(get_mini_batch_train):
            sess.run(train_op, feed_dict={X: mini_batch_x, Y: mini_batch_y})
            loss, r_2 = sess.run([loss_op, r_square], feed_dict={X: mini_batch_x, Y: mini_batch_y})
            total_loss += loss
            total_r_square += r_2
        total_loss /= n_samples
        total_r_square /= n_samples
        val_loss, val_r_square = sess.run([loss_op, r_square], feed_dict={X: x_val, Y: y_val})
        print("Epoch {}, loss : {:.4f}, val_loss : {:.4f}, r_square : {:.3f}, val_r_square : {:.3f}".format(epoch, loss, val_loss, r_2, val_r_square))
    test_r_square= sess.run(r_square, feed_dict={X: x_test, Y: y_test})
    print("test_r_square : {:.3f}".format(test_r_square))
# Out:
# Epoch 0, loss : 41145.4805, val_loss : 30303.3535, r_square : 0.884, val_r_square : 0.427
# Epoch 1, loss : 41270.7695, val_loss : 32200.0020, r_square : 0.877, val_r_square : 0.436
# Epoch 2, loss : 40242.0898, val_loss : 29702.5645, r_square : 0.901, val_r_square : 0.479
# Epoch 3, loss : 31465.8438, val_loss : 39116.4961, r_square : 0.947, val_r_square : 0.355
# Epoch 4, loss : 28144.1465, val_loss : 37053.1211, r_square : 0.961, val_r_square : 0.348
# Epoch 5, loss : 25325.8848, val_loss : 37495.3555, r_square : 0.969, val_r_square : 0.329
# Epoch 6, loss : 22514.8750, val_loss : 35392.9922, r_square : 0.976, val_r_square : 0.354
# Epoch 7, loss : 20196.2129, val_loss : 35907.6641, r_square : 0.979, val_r_square : 0.309
# Epoch 8, loss : 21432.9004, val_loss : 39053.8789, r_square : 0.977, val_r_square : 0.303
# Epoch 9, loss : 15572.0889, val_loss : 34755.7422, r_square : 0.982, val_r_square : 0.286
# Epoch 10, loss : 19597.5156, val_loss : 32804.6172, r_square : 0.979, val_r_square : 0.326
# Epoch 11, loss : 15261.0576, val_loss : 35720.9570, r_square : 0.987, val_r_square : 0.296
# Epoch 12, loss : 17617.5059, val_loss : 36520.6016, r_square : 0.982, val_r_square : 0.259
# Epoch 13, loss : 16204.7393, val_loss : 32597.4336, r_square : 0.981, val_r_square : 0.302
# Epoch 14, loss : 16779.4434, val_loss : 34822.6211, r_square : 0.979, val_r_square : 0.261
# Epoch 15, loss : 15863.0361, val_loss : 33635.2461, r_square : 0.980, val_r_square : 0.249
# Epoch 16, loss : 16769.8281, val_loss : 33509.1875, r_square : 0.979, val_r_square : 0.287
# Epoch 17, loss : 17453.6504, val_loss : 32144.2734, r_square : 0.980, val_r_square : 0.302
# Epoch 18, loss : 19786.6191, val_loss : 32666.4707, r_square : 0.978, val_r_square : 0.307
# Epoch 19, loss : 18080.2188, val_loss : 35384.4570, r_square : 0.981, val_r_square : 0.237
# Epoch 20, loss : 16815.7188, val_loss : 31907.7207, r_square : 0.978, val_r_square : 0.297
# Epoch 21, loss : 16043.7236, val_loss : 31967.2812, r_square : 0.978, val_r_square : 0.288
# Epoch 22, loss : 19192.4473, val_loss : 31249.8027, r_square : 0.976, val_r_square : 0.276
# Epoch 23, loss : 16202.5674, val_loss : 32924.8750, r_square : 0.980, val_r_square : 0.263
# Epoch 24, loss : 18595.7969, val_loss : 31117.6445, r_square : 0.975, val_r_square : 0.296
# Epoch 25, loss : 16458.6973, val_loss : 33543.0938, r_square : 0.980, val_r_square : 0.278
# Epoch 26, loss : 18673.5996, val_loss : 32573.8945, r_square : 0.979, val_r_square : 0.243
# Epoch 27, loss : 17387.5879, val_loss : 33781.9805, r_square : 0.981, val_r_square : 0.277
# Epoch 28, loss : 16861.6660, val_loss : 32282.8887, r_square : 0.981, val_r_square : 0.256
# Epoch 29, loss : 19998.6660, val_loss : 32387.8848, r_square : 0.978, val_r_square : 0.333
# Epoch 30, loss : 16222.2217, val_loss : 30765.7285, r_square : 0.979, val_r_square : 0.305
# Epoch 31, loss : 16598.4844, val_loss : 30766.3965, r_square : 0.976, val_r_square : 0.279
# Epoch 32, loss : 16497.1562, val_loss : 33517.5977, r_square : 0.982, val_r_square : 0.256
# Epoch 33, loss : 20537.4453, val_loss : 31696.5820, r_square : 0.974, val_r_square : 0.224
# Epoch 34, loss : 17996.7559, val_loss : 33575.1367, r_square : 0.982, val_r_square : 0.235
# Epoch 35, loss : 16015.4531, val_loss : 30894.6211, r_square : 0.980, val_r_square : 0.302
# Epoch 36, loss : 15130.9248, val_loss : 30313.2949, r_square : 0.978, val_r_square : 0.282
# Epoch 37, loss : 16284.8857, val_loss : 33262.2891, r_square : 0.984, val_r_square : 0.250
# Epoch 38, loss : 15589.2422, val_loss : 30854.8418, r_square : 0.977, val_r_square : 0.308
# Epoch 39, loss : 15418.7393, val_loss : 31075.6895, r_square : 0.980, val_r_square : 0.260
# Epoch 40, loss : 15843.5420, val_loss : 31844.1387, r_square : 0.981, val_r_square : 0.312
# Epoch 41, loss : 24699.6973, val_loss : 32080.8887, r_square : 0.968, val_r_square : 0.207
# Epoch 42, loss : 19042.6660, val_loss : 30829.0664, r_square : 0.979, val_r_square : 0.361
# Epoch 43, loss : 18599.3906, val_loss : 32346.1875, r_square : 0.979, val_r_square : 0.308
# Epoch 44, loss : 16531.8281, val_loss : 30768.9297, r_square : 0.980, val_r_square : 0.324
# Epoch 45, loss : 25871.2031, val_loss : 32498.7012, r_square : 0.965, val_r_square : 0.226
# Epoch 46, loss : 15724.1201, val_loss : 31381.7910, r_square : 0.979, val_r_square : 0.304
# Epoch 47, loss : 16586.5312, val_loss : 33162.8047, r_square : 0.982, val_r_square : 0.287
# Epoch 48, loss : 21568.8691, val_loss : 32517.5742, r_square : 0.973, val_r_square : 0.242
# Epoch 49, loss : 17805.5254, val_loss : 30614.6035, r_square : 0.976, val_r_square : 0.302
# Epoch 50, loss : 19899.3594, val_loss : 31202.0293, r_square : 0.976, val_r_square : 0.312
# Epoch 51, loss : 17429.3906, val_loss : 31255.3867, r_square : 0.980, val_r_square : 0.307
# Epoch 52, loss : 16632.0938, val_loss : 29823.9570, r_square : 0.980, val_r_square : 0.368
# Epoch 53, loss : 18466.6094, val_loss : 30100.8359, r_square : 0.978, val_r_square : 0.364
# Epoch 54, loss : 14802.9033, val_loss : 29974.4297, r_square : 0.976, val_r_square : 0.288
# Epoch 55, loss : 17002.4629, val_loss : 31530.1504, r_square : 0.980, val_r_square : 0.298
# Epoch 56, loss : 15937.7451, val_loss : 30197.2422, r_square : 0.977, val_r_square : 0.292
# Epoch 57, loss : 16144.1826, val_loss : 30913.3203, r_square : 0.979, val_r_square : 0.296
# Epoch 58, loss : 14311.9717, val_loss : 29300.4492, r_square : 0.974, val_r_square : 0.356
# Epoch 59, loss : 17744.6191, val_loss : 30380.6152, r_square : 0.979, val_r_square : 0.304
# Epoch 60, loss : 14764.5703, val_loss : 29410.0781, r_square : 0.973, val_r_square : 0.316
# Epoch 61, loss : 13893.1797, val_loss : 29644.2188, r_square : 0.977, val_r_square : 0.307
# Epoch 62, loss : 13340.9170, val_loss : 29983.5176, r_square : 0.984, val_r_square : 0.314
# Epoch 63, loss : 15632.8750, val_loss : 29210.3770, r_square : 0.977, val_r_square : 0.314
# Epoch 64, loss : 15098.4814, val_loss : 29413.2227, r_square : 0.977, val_r_square : 0.305
# Epoch 65, loss : 14004.2236, val_loss : 29135.5586, r_square : 0.977, val_r_square : 0.276
# Epoch 66, loss : 19012.0234, val_loss : 30136.4707, r_square : 0.973, val_r_square : 0.241
# Epoch 67, loss : 15063.5361, val_loss : 29514.5039, r_square : 0.981, val_r_square : 0.353
# Epoch 68, loss : 15365.3076, val_loss : 29479.6523, r_square : 0.974, val_r_square : 0.314
# Epoch 69, loss : 14315.7236, val_loss : 30148.6094, r_square : 0.985, val_r_square : 0.355
# Epoch 70, loss : 11707.1982, val_loss : 30211.3477, r_square : 0.987, val_r_square : 0.353
# Epoch 71, loss : 14522.4014, val_loss : 30308.1172, r_square : 0.983, val_r_square : 0.343
# Epoch 72, loss : 15318.0000, val_loss : 29791.7188, r_square : 0.981, val_r_square : 0.348
# Epoch 73, loss : 12623.3857, val_loss : 30311.3535, r_square : 0.983, val_r_square : 0.316
# Epoch 74, loss : 11888.9736, val_loss : 30455.1836, r_square : 0.986, val_r_square : 0.338
# Epoch 75, loss : 17910.8066, val_loss : 30268.3398, r_square : 0.979, val_r_square : 0.251
# Epoch 76, loss : 16747.2910, val_loss : 29545.7051, r_square : 0.979, val_r_square : 0.358
# Epoch 77, loss : 15405.0283, val_loss : 29409.7031, r_square : 0.973, val_r_square : 0.318
# Epoch 78, loss : 15073.2607, val_loss : 31111.9414, r_square : 0.983, val_r_square : 0.288
# Epoch 79, loss : 16241.6016, val_loss : 29757.8086, r_square : 0.978, val_r_square : 0.270
# Epoch 80, loss : 13584.5654, val_loss : 29734.0684, r_square : 0.980, val_r_square : 0.313
# Epoch 81, loss : 15961.3359, val_loss : 29100.4473, r_square : 0.977, val_r_square : 0.346
# Epoch 82, loss : 12169.0000, val_loss : 29913.6621, r_square : 0.983, val_r_square : 0.344
# Epoch 83, loss : 13283.0156, val_loss : 29691.9746, r_square : 0.978, val_r_square : 0.329
# Epoch 84, loss : 17753.5156, val_loss : 29456.6348, r_square : 0.974, val_r_square : 0.332
# Epoch 85, loss : 13458.8438, val_loss : 29766.4824, r_square : 0.982, val_r_square : 0.326
# Epoch 86, loss : 12079.9736, val_loss : 29893.1211, r_square : 0.987, val_r_square : 0.329
# Epoch 87, loss : 17795.6016, val_loss : 29692.9238, r_square : 0.975, val_r_square : 0.356
# Epoch 88, loss : 13830.6768, val_loss : 29008.8457, r_square : 0.984, val_r_square : 0.384
# Epoch 89, loss : 14713.4951, val_loss : 29557.3145, r_square : 0.982, val_r_square : 0.333
# Epoch 90, loss : 13534.2607, val_loss : 29094.5234, r_square : 0.983, val_r_square : 0.353
# Epoch 91, loss : 15086.4717, val_loss : 28789.2188, r_square : 0.974, val_r_square : 0.337
# Epoch 92, loss : 15935.3408, val_loss : 29025.2051, r_square : 0.973, val_r_square : 0.311
# Epoch 93, loss : 16053.6611, val_loss : 28867.4941, r_square : 0.977, val_r_square : 0.343
# Epoch 94, loss : 17210.9219, val_loss : 30028.5898, r_square : 0.979, val_r_square : 0.295
# Epoch 95, loss : 10860.9111, val_loss : 31150.3770, r_square : 0.987, val_r_square : 0.342
# Epoch 96, loss : 18753.4941, val_loss : 29379.0176, r_square : 0.976, val_r_square : 0.381
# Epoch 97, loss : 12161.3906, val_loss : 29120.6406, r_square : 0.979, val_r_square : 0.367
# Epoch 98, loss : 13533.3438, val_loss : 30023.8125, r_square : 0.982, val_r_square : 0.348
# Epoch 99, loss : 16577.9941, val_loss : 29899.9277, r_square : 0.981, val_r_square : 0.338
# test_r_square : 0.746

# %% [markdown]
# ## Task5 MNIST Dataset

# %%
from keras.datasets import mnist

# MNIST dataset 
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)
x_train = x_train.astype(np.float32)
x_test = x_test.astype(np.float32)
x_train /= 255
x_test /= 255
enc = OneHotEncoder(handle_unknown='ignore')
y_train_one_hot = enc.fit_transform(y_train[:, np.newaxis]).toarray()
y_test_one_hot = enc.transform(y_test[:, np.newaxis]).toarray()

# %%
#train , val
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train_one_hot, test_size=0.4, shuffle=True, random_state=42)
print(x_train.shape) 
print(x_val.shape)
# Out:
# (36000, 784)
# (24000, 784)

# %%
learning_rate = 0.01
batch_size = 10
num_epochs = 10

n_hidden1 = 50
n_hidden2 = 100
n_input = x_train.shape[1]
n_samples = x_train.shape[0]
n_classes = 10

#tf tensor
X = tf.placeholder("float", [None, n_input])
Y = tf.placeholder("float", [None, n_classes])

#dataloader
get_mini_batch_train = GetMiniBatch(x_train, y_train, batch_size=batch_size)

# model architecture
def example_net(x):
    """
    単純な3層ニューラルネットワーク
    """

    weights = {
        'w1': tf.Variable(tf.random_normal([n_input, n_hidden1])),
        'w2': tf.Variable(tf.random_normal([n_hidden1, n_hidden2])),
        'w3': tf.Variable(tf.random_normal([n_hidden2, n_classes]))
    }
    biases = {
        'b1': tf.Variable(tf.random_normal([n_hidden1])),
        'b2': tf.Variable(tf.random_normal([n_hidden2])),
        'b3': tf.Variable(tf.random_normal([n_classes]))
    }

    layer_1 = tf.add(tf.matmul(x, weights['w1']), biases['b1'])
    layer_1 = tf.nn.relu(layer_1)
    layer_2 = tf.add(tf.matmul(layer_1, weights['w2']), biases['b2'])
    layer_2 = tf.nn.relu(layer_2)
    layer_output = tf.matmul(layer_2, weights['w3']) + biases['b3'] 
    return layer_output

#model 
logits = example_net(X)

# loss 
loss_op = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=Y, logits=logits))

#optimizer
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss_op)

#not trained model's result
correct_pred = tf.equal(tf.argmax(Y, 1), tf.argmax(tf.nn.softmax(logits), 1))
#evaluation metric 
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

#model training 
init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(num_epochs):
        total_batch = np.ceil(X_train.shape[0]/batch_size).astype(np.int32)
        total_loss = 0
        total_acc = 0
        for i, (mini_batch_x, mini_batch_y) in enumerate(get_mini_batch_train):
            sess.run(train_op, feed_dict={X: mini_batch_x, Y: mini_batch_y})
            loss, acc = sess.run([loss_op, accuracy], feed_dict={X: mini_batch_x, Y: mini_batch_y})
            total_loss += loss
            total_acc += acc
        total_loss /= n_samples
        total_acc /= n_samples
        val_loss, val_acc = sess.run([loss_op, accuracy], feed_dict={X: x_val, Y: y_val})
        print("Epoch {}, loss : {:.4f}, val_loss : {:.4f}, acc : {:.3f}, val_acc : {:.3f}".format(epoch, loss, val_loss, acc, val_acc))
    test_acc = sess.run(accuracy, feed_dict={X: x_test, Y: y_test_one_hot})
    print("test_acc : {:.3f}".format(test_acc))
# Out:
# WARNING:tensorflow:From C:\Python311\Lib\site-packages\tensorflow\python\util\dispatch.py:1260: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# Epoch 0, loss : 0.6830, val_loss : 1.1107, acc : 0.700, val_acc : 0.657
# Epoch 1, loss : 0.9190, val_loss : 1.0353, acc : 0.700, val_acc : 0.707
# Epoch 2, loss : 0.6696, val_loss : 0.8157, acc : 0.700, val_acc : 0.760
# Epoch 3, loss : 0.0365, val_loss : 0.5563, acc : 1.000, val_acc : 0.862
# Epoch 4, loss : 0.0403, val_loss : 0.4110, acc : 1.000, val_acc : 0.896
# Epoch 5, loss : 0.0243, val_loss : 0.4312, acc : 1.000, val_acc : 0.899
# Epoch 6, loss : 0.0347, val_loss : 0.4196, acc : 1.000, val_acc : 0.906
# Epoch 7, loss : 0.0221, val_loss : 0.3995, acc : 1.000, val_acc : 0.904
# Epoch 8, loss : 0.0191, val_loss : 0.3485, acc : 1.000, val_acc : 0.914
# Epoch 9, loss : 0.0205, val_loss : 0.3619, acc : 1.000, val_acc : 0.915
# test_acc : 0.918
